# %% [markdown]
# # Домашняя работа №1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Изобразите с помощью matplotlib. Изобразите точку x + 2y + 3z. Найдите угол между векторами x, y и x, z.

# %% [markdown]
# ***изобразите точку***

# %%
x = np.array([1,1])
y = np.array([2, 0])
z = np.array([0,2])

# %%
figure = x + 2*y + 3*z
figure
# Out:
# array([5, 7])

# %%
plt.plot(figure[0], figure[1], 'ro')

# %% [markdown]
# ***угол между векторами***

# %%
ax = plt.axes()

plt.xlim( [0, 5] )
plt.ylim( [0, 4] )

ax.arrow( 0, 0, x[0], x[1], head_width=0.1, head_length=0.2, fc='k', ec='k' )
ax.arrow( 0, 0, y[0], y[1], head_width=0.1, head_length=0.2, fc='k', ec='k' )
ax.arrow( 0, 0, z[0], z[1], head_width=0.1, head_length=0.2, fc='k', ec='k' )

plt.show()

# %%
xLength = np.linalg.norm( x )
yLength = np.linalg.norm( y )
cosine_xy = np.dot( x, y ) / ( xLength * yLength )
np.arccos( cosine_xy ) * 360 / 2 / np.pi
# Out:
# 45.00000000000001

# %%
xLength = np.linalg.norm( x )
zLength = np.linalg.norm( z )
cosine_xz = np.dot( x, z ) / ( xLength * zLength )
np.arccos( cosine_xz ) * 360 / 2 / np.pi
# Out:
# 45.00000000000001

# %% [markdown]
# ***Неправильно понял задание. Оставить для примера графика. Изобразите с помощью matplotlib. Изобразите точку x + 2y + 3z.***

# %%
plt.scatter(1, 2, 3)
#grid1 = plt.grid(True)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
np.random.seed(123)
x = np.random.randint(1)
y = np.random.randint(2)
z = np.random.randint(3)
s = np.random.randint(10, 100, 20) #Размер маркера

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, s=s)

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Найдите собственные значения и собственные вектора матриц (необходимо решение на numpy и решение по алгоритму на бумажке). Для матрицы 3x3 можно посмотреть на корни характеристического многочлена, посчитанные в numpy.

# %%
m1 = np.array([[2, 2],
               [1, 3]])

# %%
w1, v1 = np.linalg.eig(m1)

# %%
for i in range(len(w1)):
    print("Собственное значение " + str(w1[i]))
    print("соответствующий ему собственный вектор " + str(v1[:,i]))
# Out:
# Собственное значение 1.0
# соответствующий ему собственный вектор [-0.89 0.45]
# Собственное значение 4.0
# соответствующий ему собственный вектор [-0.71 -0.71]

# %%
m2 = np.array([[4, 1, -1],
               [1, 4, -1],
               [-1, -1, 4]])

# %%
w2, v2 = np.linalg.eig(m2)

# %%
for i in range(len(w2)):
    print("Собственное значение " + str(w2[i]))
    print("соответствующий ему собственный вектор " + str(v2[:,i]))
# Out:
# Собственное значение 2.999999999999999
# соответствующий ему собственный вектор [-0.82 0.41 -0.41]
# Собственное значение 5.999999999999997
# соответствующий ему собственный вектор [0.58 0.58 -0.58]
# Собственное значение 2.9999999999999996
# соответствующий ему собственный вектор [-0.28 0.80 0.53]

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Найдите сингулярное разложение матрицы.

# %%
import pylab as pl
from scipy import linalg
from sklearn.datasets import load_digits

# %%
m3 = np.array([[1, 2],
               [2, 3]])

# %%
U, s, V = np.linalg.svd(m3)
n_component = 1
S = np.diag(s)[:, :n_component]
V = V[:n_component, :]
A = U.dot(S.dot(V))
print(A)
# Out:
# [[1.17 1.89]
#  [1.89 3.07]]
